# %%
from __future__ import division
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import numpy as np
import h5py
import analysis

def histgrid(filename, shot):
    f=h5py.File(filename,'r')
    #iteration 0
    #images = np.array([[m['data/Hamamatsu/shots/0'].value for m in i['measurements'].itervalues()] for i in f['iterations'].itervalues()])
    #print images.shape
    data = np.array([[m['analysis/squareROIsums'].value for m in i['measurements'].itervalues()] for i in f['iterations'].itervalues()])
    fig = plt.figure(figsize=(30,30))
    roidata = data[0,:,shot,:]
    analysis.histogram_grid_plot(fig, roidata, 7, 7)
    f.close()

# %%
reload(analysis)
# Out:
# <module 'analysis' from 'analysis.py'>

# %%
histgrid(r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_20_24_55_background_yes780_yes852_yesAntihelmholtz\results.hdf5',0)

# %%
histgrid(r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_21_50_14_background_new_filter\results.hdf5',0)

# %%
histgrid(r'D:\users\Public\AQuA data\2014 data\2014_06_11\2014_06_11_06_26_43_retention\results.hdf5',0)
# Out:
# analysis.py:673: RuntimeWarning: divide by zero encountered in double_scalars
#   g = a/(w*numpy.sqrt(2*numpy.pi))*numpy.exp(-0.5*(x-x0)**2/w**2)  # normalize
# analysis.py:673: RuntimeWarning: divide by zero encountered in true_divide
#   g = a/(w*numpy.sqrt(2*numpy.pi))*numpy.exp(-0.5*(x-x0)**2/w**2)  # normalize
# analysis.py:673: RuntimeWarning: invalid value encountered in true_divide
#   g = a/(w*numpy.sqrt(2*numpy.pi))*numpy.exp(-0.5*(x-x0)**2/w**2)  # normalize
# analysis.py:673: RuntimeWarning: invalid value encountered in multiply
#   g = a/(w*numpy.sqrt(2*numpy.pi))*numpy.exp(-0.5*(x-x0)**2/w**2)  # normalize

# %%
histgrid(r'D:\users\Public\AQuA data\2014 data\2014_06_11\2014_06_11_06_48_20_Retention_old_settings\results.hdf5',0)

# %%
reload(analysis)
histgrid(r'D:\users\Public\AQuA data\2014 data\2014_06_11\2014_06_11_06_48_20_Retention_old_settings\results.hdf5',0)
# Out:
# (15089.104991634131, 200023.22727272732, 1519.9890561010209, 19187.316115702477, 4499.5000000000036, 268.151701883474)
# [  14302.83524433   23593.36508826     470.11710445   15269.36007833
#   181017.66821391    1695.82802468]
# (14936.347107438016, 746416.00000000012, 1627.4485975418308, 30016.431818181816, 24674.90909090907, 7519.9897191097607)
# [  14698.76243417  676631.97757553    1444.95511507   17513.29625984
#    69632.70915322    1117.59402433]
# (16527.470025635968, 595318.63636363612, 1743.8820246120194, 31133.332167832163, 50363.181818181802, 6293.698091680747)
# [  16418.24756867  580251.59384382    1754.03428293   37662.30041235
#   181265.50968091   25650.89088689]
# (17824.635846038018, 489213.13636363647, 2070.6559195470845, 28664.287433155081, 17218.68181818182, 3346.0536692236519)
# [  17140.59786495  332305.45919432    1648.4848885    19313.85426485
#   164117.75159475    2436.56060991]
# ...

# %%
reload(analysis)
histgrid(r'D:\users\Public\AQuA data\2014 data\2014_06_11\2014_06_11_06_26_43_retention\results.hdf5',0)
