# %%
import h5py
f=h5py.File('results.hdf5','r')

# %%
for measurement in f['iterations/0/measurements'].values()[:5]:
    for shot in measurement['data/Hamamatsu/shots'].values():
        figure()
        imshow(shot)

# %%
sumpic = numpy.sum(numpy.array([[shot for shot in measurement['data/Hamamatsu/shots'].values()] for measurement in f['iterations/0/measurements'].values()]),axis=(0,1))
imshow(sumpic)
