# %%
from __future__ import division
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import h5py

def showsum(filename):
    # import images from hdf5 file
    f = h5py.File(filename,'r')
    images = np.array([[[s.value for s in m['data/Hamamatsu/shots'].itervalues()] for m in i['measurements'].itervalues()] for i in f['iterations'].itervalues()])
    #print images.shape
    f.close()
    return np.sum(images[0,:,0,:,:],axis=0)
    #plt.matshow(sum0)
    
filenames = [r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_18_23_06_background_no780_noAntihelmholtz_no852\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_18_45_35_background_no780_noAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_19_04_25_background_no852_noAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_19_48_59_background_no852_yesAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_20_01_21_background_no780_yesAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_20_15_08_background_yes780_yes852_noAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_20_24_55_background_yes780_yes852_yesAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_20_58_57_background_TiSapphONLY_no852_yesAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_21_16_47_background_SHGonly_no852_yesAntihelmholtz\results.hdf5',
             r'D:\users\Public\AQuA data\2014 data\2014_06_09\2014_06_09_21_50_14_background_new_filter\results.hdf5']

images = np.array([showsum(f) for f in filenames])

# %%
myMax = np.amax(images)
myMin = np.amin(images)
fig = plt.figure(figsize=(10*len(filenames),5))
gs1 = GridSpec(1, len(filenames), top=.94)

for i,im in enumerate(images):
    ax = fig.add_subplot(gs1[0, i])
    ax.matshow(im,vmin=myMin,vmax=myMax)
    ax.set_title(filenames[i].split('\\')[-2][31:]) # size=font)
