# %%
from __future__ import division
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# import images from hdf5 file
import h5py
f = h5py.File(r'E:\data\2014_06_09\2014_06_09_19_04_25_background_no852_noAntihelmholtz\results.hdf5','r')
images = np.array([[[s.value for s in m['data/Hamamatsu/shots'].itervalues()] for m in i['measurements'].itervalues()] for i in f['iterations'].itervalues()])
print images.shape
f.close()
# Out:
# (1L, 500L, 2L, 50L, 103L)

# %%
sum0=np.sum(images[0,:,0,:,:],axis=0)
plt.matshow(sum0)

# %%
sum1=np.sum(images[0,:,1,:,:],axis=0)
plt.matshow(sum1)
